# %%
import os

# %%
# %pwd
# Out:
# 'd:\\Kidney-Disease-Classification-MLflow-DVC\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'd:\\Kidney-Disease-Classification-MLflow-DVC'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class TrainingConfig:
    root_dir: Path
    trained_model_path: Path
    updated_base_model_path: Path
    training_data: Path
    params_epochs: int
    params_batch_size: int
    params_is_augmentation: bool
    params_image_size: list

# %%
from cnnClassifier.constants import *
from cnnClassifier.utils.common import read_yaml, create_directories
import tensorflow as tf

# %%
class ConfigurationManager:

    def __init__(
        self,
        config_filepath=CONFIG_FILE_PATH,
        params_filepath=PARAMS_FILE_PATH
    ):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])

    def get_training_config(self) -> TrainingConfig:

        training = self.config.training
        prepare_base_model = self.config.prepare_base_model
        params = self.params

        training_data = os.path.join(
            self.config.data_ingestion.unzip_dir,
            "kidney-ct-scan-image"
        )

        create_directories([Path(training.root_dir)])

        training_config = TrainingConfig(
            root_dir=Path(training.root_dir),
            trained_model_path=Path(training.trained_model_path),
            updated_base_model_path=Path(
                prepare_base_model.updated_base_model_path
            ),
            training_data=Path(training_data),
            params_epochs=params.EPOCHS,
            params_batch_size=params.BATCH_SIZE,
            params_is_augmentation=params.AUGMENTATION,
            params_image_size=params.IMAGE_SIZE
        )

        return training_config

# %%
import os
import urllib.request as request
from zipfile import ZipFile
import tensorflow as tf
import time

# %%
class Training:

    def __init__(self, config: TrainingConfig):
        self.config = config

    def get_base_model(self):
        self.model = tf.keras.models.load_model(
            self.config.updated_base_model_path
        )

    def train_valid_generator(self):

        datagenerator_kwargs = dict(
            rescale=1.0 / 255,
            validation_split=0.20
        )

        dataflow_kwargs = dict(
            target_size=self.config.params_image_size[:-1],
            batch_size=self.config.params_batch_size,
            interpolation="bilinear"
        )

        valid_datagenerator = tf.keras.preprocessing.image.ImageDataGenerator(
            **datagenerator_kwargs
        )

        self.valid_generator = valid_datagenerator.flow_from_directory(
            directory=self.config.training_data,
            subset="validation",
            shuffle=False,
            **dataflow_kwargs
        )

        if self.config.params_is_augmentation:

            train_datagenerator = tf.keras.preprocessing.image.ImageDataGenerator(
                rotation_range=40,
                horizontal_flip=True,
                width_shift_range=0.2,
                height_shift_range=0.2,
                shear_range=0.2,
                zoom_range=0.2,
                **datagenerator_kwargs
            )

        else:
            train_datagenerator = valid_datagenerator

        self.train_generator = train_datagenerator.flow_from_directory(
            directory=self.config.training_data,
            subset="training",
            shuffle=True,
            **dataflow_kwargs
        )

    @staticmethod
    def save_model(path: Path, model: tf.keras.Model):
        model.save(path)

    def train(self):

        self.steps_per_epoch = (
            self.train_generator.samples //
            self.train_generator.batch_size
        )

        self.validation_steps = (
            self.valid_generator.samples //
            self.valid_generator.batch_size
        )

        self.model.fit(
            self.train_generator,
            epochs=self.config.params_epochs,
            steps_per_epoch=self.steps_per_epoch,
            validation_steps=self.validation_steps,
            validation_data=self.valid_generator,
            callbacks=None
        )

        self.save_model(
            path=self.config.trained_model_path,
            model=self.model
        )

# %%
try:
    config = ConfigurationManager()
    training_config = config.get_training_config()

    training = Training(config=training_config)

    training.get_base_model()

    training.train_valid_generator()

    training.train()

except Exception as e:
    raise e
# Out:
# [2026-08-08 19:32:08,901: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2026-08-08 19:32:08,913: INFO: common: yaml file: params.yaml loaded successfully]
# [2026-08-08 19:32:08,919: INFO: common: created directory at: artifacts]
# [2026-08-08 19:32:08,924: INFO: common: created directory at: artifacts\training]
# Found 93 images belonging to 2 classes.
# Found 372 images belonging to 2 classes.
# Epoch 1/100
# 23/23 [==============================] - 112s 5s/step - loss: 12.2554 - accuracy: 0.5393 - val_loss: 3.2870 - val_accuracy: 0.4375
# Epoch 2/100
# 23/23 [==============================] - 106s 5s/step - loss: 7.2946 - accuracy: 0.7219 - val_loss: 28.4595 - val_accuracy: 0.4000
# Epoch 3/100
# 23/23 [==============================] - 107s 5s/step - loss: 4.5387 - accuracy: 0.7500 - val_loss: 0.8064 - val_accuracy: 0.9375
# Epoch 4/100
# 23/23 [==============================] - 107s 5s/step - loss: 2.3055 - accuracy: 0.8062 - val_loss: 1.4925 - val_accuracy: 0.5875
# Epoch 5/100
# 23/23 [==============================] - 106s 5s/step - loss: 3.9152 - accuracy: 0.7360 - val_loss: 0.5125 - val_accuracy: 0.8875
# Epoch 6/100
# 23/23 [==============================] - 106s 5s/step - loss: 2.5456 - accuracy: 0.8315 - val_loss: 3.0914 - val_accuracy: 0.6000
# Epoch 7/100
# 23/23 [==============================] - 104s 5s/step - loss: 2.1561 - accuracy: 0.8287 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 8/100
# 23/23 [==============================] - 105s 5s/step - loss: 2.4358 - accuracy: 0.8596 - val_loss: 0.0335 - val_accuracy: 0.9625
# Epoch 9/100
# 23/23 [==============================] - 105s 5s/step - loss: 0.2968 - accuracy: 0.9466 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 10/100
# 23/23 [==============================] - 105s 5s/step - loss: 3.7793 - accuracy: 0.7697 - val_loss: 4.8844 - val_accuracy: 0.5000
# Epoch 11/100
# 23/23 [==============================] - 107s 5s/step - loss: 0.4848 - accuracy: 0.9326 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 12/100
# 23/23 [==============================] - 106s 5s/step - loss: 0.4177 - accuracy: 0.9157 - val_loss: 4.3706 - val_accuracy: 0.6000
# Epoch 13/100
# 23/23 [==============================] - 105s 5s/step - loss: 0.4138 - accuracy: 0.9382 - val_loss: 9.6985 - val_accuracy: 0.6000
# Epoch 14/100
# 23/23 [==============================] - 105s 5s/step - loss: 0.9237 - accuracy: 0.8904 - val_loss: 0.1237 - val_accuracy: 0.9375
# Epoch 15/100
# 23/23 [==============================] - 106s 5s/step - loss: 0.6411 - accuracy: 0.9185 - val_loss: 3.8978e-05 - val_accuracy: 1.0000
# Epoch 16/100
# 23/23 [==============================] - 105s 5s/step - loss: 0.1442 - accuracy: 0.9719 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 17/100
# 23/23 [==============================] - 105s 5s/step - loss: 0.1369 - accuracy: 0.9719 - val_loss: 5.8382e-05 - val_accuracy: 1.0000
# Epoch 18/100
# 23/23 [==============================] - 104s 5s/step - loss: 0.0682 - accuracy: 0.9803 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 19/100
# 23/23 [==============================] - 104s 5s/step - loss: 0.0726 - accuracy: 0.9831 - val_loss: 3.4450e-04 - val_accuracy: 1.0000
# Epoch 20/100
#
- val_loss: 0.0215 - val_accuracy: 1.0000
# Epoch 58/100
# 23/23 [==============================] - 120s 5s/step - loss: 0.0391 - accuracy: 0.9972 - val_loss: 0.0152 - val_accuracy: 1.0000
# Epoch 59/100
# 23/23 [==============================] - 120s 5s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0329 - val_accuracy: 0.9875
# Epoch 60/100
# 23/23 [==============================] - 122s 5s/step - loss: 0.0477 - accuracy: 0.9888 - val_loss: 0.0148 - val_accuracy: 1.0000
# Epoch 61/100
# 23/23 [==============================] - 119s 5s/step - loss: 0.0060 - accuracy: 0.9972 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 62/100
# 23/23 [==============================] - 121s 5s/step - loss: 0.0321 - accuracy: 0.9944 - val_loss: 0.0199 - val_accuracy: 1.0000
# Epoch 63/100
# 23/23 [==============================] - 142s 6s/step - loss: 0.0250 - accuracy: 0.9916 - val_loss: 1.0517e-05 - val_accuracy: 1.0000
# Epoch 64/100
# 23/23 [==============================] - 124s 5s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 65/100
# 23/23 [==============================] - 120s 5s/step - loss: 0.0099 - accuracy: 0.9944 - val_loss: 7.0915e-04 - val_accuracy: 1.0000
# Epoch 66/100
# 23/23 [==============================] - 115s 5s/step - loss: 0.0576 - accuracy: 0.9860 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 67/100
# 23/23 [==============================] - 123s 5s/step - loss: 0.0168 - accuracy: 0.9916 - val_loss: 0.0435 - val_accuracy: 0.9750
# Epoch 68/100
# 23/23 [==============================] - 119s 5s/step - loss: 0.0637 - accuracy: 0.9755 - val_loss: 0.0186 - val_accuracy: 1.0000
# Epoch 69/100
# 23/23 [==============================] - 120s 5s/step - loss: 0.0666 - accuracy: 0.9888 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 70/100
# 23/23 [==============================] - 118s 5s/step - loss: 0.0406 - accuracy: 0.9888 - val_loss: 0.2491 - val_accuracy: 0.8875
# Epoch 71/100
# 23/23 [==============================] - 117s 5s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 72/100
# 23/23 [==============================] - 119s 5s/step - loss: 0.0033 - accuracy: 0.9972 - val_loss: 0.0263 - val_accuracy: 1.0000
# Epoch 73/100
# 23/23 [==============================] - 122s 5s/step - loss: 0.0552 - accuracy: 0.9837 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 74/100
# 23/23 [==============================] - 118s 5s/step - loss: 0.0141 - accuracy: 0.9944 - val_loss: 3.1547e-04 - val_accuracy: 1.0000
# Epoch 75/100
# 23/23 [==============================] - 119s 5s/step - loss: 0.0188 - accuracy: 0.9944 - val_loss: 9.2739e-06 - val_accuracy: 1.0000
# Epoch 76/100
# 23/23 [==============================] - 123s 5s/step - loss: 0.0058 - accuracy: 0.9972 - val_loss: 8.1236e-04 - val_accuracy: 1.0000
# Epoch 77/100
# 23/23 [==============================] - 108s 5s/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 2.9599e-04 - val_accuracy: 1.0000
# Epoch 78/100
# 23/23 [==============================] - 115s 5s/step - loss: 0.0261 - accuracy: 0.9916 - val_loss: 0.1045 - val_accuracy: 0.9500
# Epoch 79/100
# 23/23 [==============================] - 114s 5s/step - loss: 0.0167 - accuracy: 0.9916 - val_loss: 0.0426 - val_accuracy: 0.9750
# Epoch 80/100
# 23/23 [==============================] - 109s 5s/step - loss: 0.0126 - accuracy: 0.9888 - val_loss: 7.9444e-04 - val_accuracy: 1.0000
# Epoch 81/100
# 23/23 [==============================] - 106s 5s/step - loss: 0.0032 - accuracy: 0.9972 - val_loss: 0.0289 - val_accuracy: 1.0000
# Epoch 82/100
# 23/23 [==============================] - 111s 5s/step - loss: 0.0142 - accuracy: 0.9916 - val_loss: 4.3237e-04 - val_accuracy: 1.0000
# Epoch 83/100
# 23/23 [==============================] - 120s 5s/step - loss: 0.0415 - accuracy: 0.9916 - val_loss: 0.0181 - val_accuracy: 1.0000
# Epoch 84/100
# 23/23 [==============================] - 106s 5s/step - loss: 0.0080 - accuracy: 0.9973 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 85/100
# 23/23 [==============================] - 97s 4s/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 86/100
# 23/23 [==============================] - 100s 4s/step - loss: 3.1713e-04 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 87/100
# 23/23 [==============================] - 102s 4s/step - loss: 0.0249 - accuracy: 0.9888 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 88/100
# 23/23 [==============================] - 105s 5s/step - loss: 0.0286 - accuracy: 0.9918 - val_loss: 0.0852 - val_accuracy: 0.9500
# Epoch 89/100
# 23/23 [==============================] - 103s 4s/step - loss: 0.0517 - accuracy: 0.9860 - val_loss: 0.0383 - val_accuracy: 0.9750
# Epoch 90/100
# 23/23 [==============================] - 98s 4s/step - loss: 0.0058 - accuracy: 0.9972 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 91/100
# 23/23 [==============================] - 123s 5s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0226 - val_accuracy: 1.0000
# Epoch 92/100
# 23/23 [==============================] - 126s 5s/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.1018 - val_accuracy: 0.9500
# Epoch 93/100
# 23/23 [==============================] - 120s 5s/step - loss: 0.0047 - accuracy: 0.9973 - val_loss: 0.1900 - val_accuracy: 0.9000
# Epoch 94/100
# 23/23 [==============================] - 116s 5s/step - loss: 0.0082 - accuracy: 0.9972 - val_loss: 1.7948e-04 - val_accuracy: 1.0000
# Epoch 95/100
# 23/23 [==============================] - 97s 4s/step - loss: 0.0309 - accuracy: 0.9888 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 96/100
# 23/23 [==============================] - 118s 5s/step - loss: 0.0083 - accuracy: 0.9972 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 97/100
# 23/23 [==============================] - 118s 5s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0695 - val_accuracy: 0.9625
# Epoch 98/100
# 23/23 [==============================] - 116s 5s/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0234 - val_accuracy: 1.0000
# Epoch 99/100
# 23/23 [==============================] - 112s 5s/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 5.6368e-04 - val_accuracy: 1.0000
# Epoch 100/100
# 23/23 [==============================] - 116s 5s/step - loss: 0.0252 - accuracy: 0.9916 - val_loss: 2.0181e-04 - val_accuracy: 1.0000
